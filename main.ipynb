# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
merge_100 = pd.read_csv('./results/merge_100.csv', index_col=False)

# %%
plt.plot(merge_100['t'], merge_100['Time'])
